# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
number = 42
print(f'The answer is {number}')    

H =int('123') + 1  
print(H)
# Out:
# The answer is 42
# 124

# %% [markdown]
# Hola mi nombre es raul y le estoy explicando a cris como se hace un jupyter
# ## yuhiiiiii
