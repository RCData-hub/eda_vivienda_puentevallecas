# %% [markdown]
# # __EVOLUCIÓN DEL PRECIO DE LA VIVIENDA EN PUENTE DE VALLECAS POR DISTRITO__
#
# ---

# %% [markdown]
# Realizaremos un EDA simple para ver la evolucion temporal del precio de la vivienda en el distrito de Puente de Vallecas (Madrid) entre los años 2007 y 2025 utilizando los datos obtenidos del portal público del [Ayuntamiento de Madrid](https://servpub.madrid.es/CSEBD_WBINTER/seleccionSerie.html?numSerie=0504020100060).

# %% [markdown]
# Importamos los sospechosos habituales.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importamos los datos obtenidos del portal.

# %%
df_nuevas = pd.read_csv('data/clean/puente_nuevas_raw.csv', delimiter = ';')
df_usadas = pd.read_csv('data/clean/puente_usadas_raw.csv', delimiter = ';')
df_total = pd.read_csv('data/clean/puente_total_raw.csv', delimiter = ';')

# %%
df_nuevas.head()
# Out:
#                Barrio            Distrito      2007      2008      2009  \
# 0  Puente de Vallecas  Puente de Vallecas  3.520,66  3.647,39  3.154,33
# 1  Puente de Vallecas           Entrevías         -         -         -
# 2  Puente de Vallecas           San Diego         -         -         -
# 3  Puente de Vallecas     Palomeras Bajas         -         -         -
# 4  Puente de Vallecas   Palomeras Sureste         -         -         -
#
#        2010      2011      2012     2013     2014      2015      2016  \
# 0  2.479,08  2.358,57  1.854,64  1.403,8  1.370,9  1.331,88  1.273,55
# 1         -         -         -        -        -         -  1.123,87
# 2         -         -         -        -        -         -  1.239,07
# 3         -         -         -        -        -         -  1.315,91
# 4         -         -         -        -        -         -  1.227,77
#
#        2017      2018      2019      2020      2021      2022      2023  \
# 0  1.365,67  1.617,61  1.826,79  1.888,57  1.859,65  2.196,98  2.181,35
# 1  1.165,69  1.453,86  1.692,83  1.559,26  1.704,96  1.761,14  1.942,03
# 2  1.407,87  1.637,47   1.874,6  1.822,36  1.868,34   2.077,4  2.424,44
# 3  1.529,72  1.840,48  1.884,46  1.962,93  1.901,85  2.072,97   1.928,7
# 4  1.251,09   1.710,6  1.668,94  1.779,87  1.999,01  2.745,61  2.506,02
#
#        2024
# 0  2.463,26
# 1  2.155,32
# 2  2.629,51
# 3  2.387,19
# 4  2.310,02

# %%
df_usadas.head()
# Out:
#                Barrio            Distrito      2007      2008      2009  \
# 0  Puente de Vallecas  Puente de Vallecas  3.256,39  2.880,98  2.246,55
# 1  Puente de Vallecas           Entrevías         -         -         -
# 2  Puente de Vallecas           San Diego         -         -         -
# 3  Puente de Vallecas     Palomeras Bajas         -         -         -
# 4  Puente de Vallecas   Palomeras Sureste         -         -         -
#
#        2010      2011      2012      2013     2014      2015      2016  \
# 0  2.238,65  2.065,33  1.653,73  1.350,26  1.225,4  1.206,13  1.320,89
# 1         -         -         -         -        -         -  1.144,19
# 2         -         -         -         -        -         -   1.331,9
# 3         -         -         -         -        -         -  1.343,36
# 4         -         -         -         -        -         -  1.247,72
#
#        2017      2018      2019      2020      2021      2022      2023  \
# 0  1.428,32  1.644,77  1.846,07  1.914,69  1.925,15  2.081,79   2.136,7
# 1  1.242,04  1.310,91  1.634,26  1.835,46  1.765,16   1.884,6  1.984,68
# 2  1.505,35  1.659,41  1.960,52  2.022,03  2.070,82  2.172,96  2.206,35
# 3  1.508,26  1.743,54   1.867,3  1.963,13  2.016,56  2.138,83   2.247,1
# 4  1.321,75  1.545,79  1.645,75  1.743,52  1.760,26  1.850,62  1.937,92
#
#        2024
# 0  2.439,69
# 1  2.125,59
# 2  2.452,35
# 3  2.503,51
# 4  2.239,13

# %%
df_total.head()
# Out:
#                Barrio            Distrito      2007      2008      2009  \
# 0  Puente de Vallecas  Puente de Vallecas  3.282,45  3.047,62  2.537,32
# 1  Puente de Vallecas           Entrevías         -         -         -
# 2  Puente de Vallecas           San Diego         -         -         -
# 3  Puente de Vallecas     Palomeras Bajas         -         -         -
# 4  Puente de Vallecas   Palomeras Sureste         -         -         -
#
#        2010      2011      2012     2013     2014      2015      2016  \
# 0  2.349,45  2.235,54  1.767,23  1.378,7  1.307,4  1.252,73  1.306,74
# 1         -         -         -        -        -         -  1.132,85
# 2         -         -         -        -        -         -  1.295,09
# 3         -         -         -        -        -         -  1.337,43
# 4         -         -         -        -        -         -  1.243,79
#
#        2017      2018      2019      2020      2021      2022      2023  \
# 0  1.412,75  1.637,04  1.841,52  1.908,39   1.908,5  2.110,69  2.146,86
# 1  1.207,88  1.386,87   1.660,4  1.712,29  1.735,19  1.826,99  1.963,83
# 2  1.468,96   1.652,3   1.930,5  1.953,47  2.014,65  2.143,48  2.278,05
# 3  1.512,37  1.761,74  1.870,45  1.963,09   1.995,5  2.128,24  2.200,42
# 4  1.310,56  1.592,74  1.648,98  1.748,82  1.832,09  2.148,95  1.994,56
#
#        2024
# 0  2.444,16
# 1  2.138,82
# 2  2.508,13
# 3  2.487,89
# 4  2.245,45

# %%
df_total.drop(['Barrio'],axis='columns', inplace=True)

melted_df_total = df_total.melt(id_vars=['Distrito'],
                    var_name='Year', value_name='€_m2')
melted_df_total
# Out:
#                Distrito  Year      €_m2
# 0    Puente de Vallecas  2007  3.282,45
# 1             Entrevías  2007         -
# 2             San Diego  2007         -
# 3       Palomeras Bajas  2007         -
# 4     Palomeras Sureste  2007         -
# ..                  ...   ...       ...
# 121           San Diego  2024  2.508,13
# 122     Palomeras Bajas  2024  2.487,89
# 123   Palomeras Sureste  2024  2.245,45
# 124            Portazgo  2024  2.313,93
# 125            Numancia  2024  2.730,31
#
# [126 rows x 3 columns]

# %%
melted_df_total['€_m2'] = melted_df_total['€_m2'].str.replace('.', '')
melted_df_total['€_m2'] = melted_df_total['€_m2'].str.replace(',', '.')
melted_df_total['€_m2'] = melted_df_total['€_m2'].str.replace('-', '0')

melted_df_total
# Out:
#                Distrito  Year     €_m2
# 0    Puente de Vallecas  2007  3282.45
# 1             Entrevías  2007        0
# 2             San Diego  2007        0
# 3       Palomeras Bajas  2007        0
# 4     Palomeras Sureste  2007        0
# ..                  ...   ...      ...
# 121           San Diego  2024  2508.13
# 122     Palomeras Bajas  2024  2487.89
# 123   Palomeras Sureste  2024  2245.45
# 124            Portazgo  2024  2313.93
# 125            Numancia  2024  2730.31
#
# [126 rows x 3 columns]

# %%
melted_df_total['€_m2'].astype(float)
# Out:
# 0      3282.45
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.00
#         ...
# 121    2508.13
# 122    2487.89
# 123    2245.45
# 124    2313.93
# 125    2730.31
# Name: €_m2, Length: 126, dtype: float64

# %%
plt.figure(figsize=(12,8))         
sns.lineplot(melted_df_total, x='Year', y='€_m2', hue ='Distrito')
plt.ylim(5, 25)
plt.show()
